# %% [markdown]
# # DATA OVERVIEW

# %%
import pandas as pd

# %%
df = pd.read_csv("Data/REGION.xls")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-9e785b9dd51c> in <module>
# ----> 1 df = pd.read_csv("Data/REGION.xls")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...

# %%
df = pd.read_excel("DATA/REGION.xls")

# %%
df.head()
# Out:
#    Region Code Region Name
# 0            0      Canada
# 1            1     Western
# 2            2    Southern
# 3            3   Northeast
# 4            4     Central

# %%
df.describe()
# Out:
#        Region Code
# count     6.000000
# mean      2.500000
# std       1.870829
# min       0.000000
# 25%       1.250000
# 50%       2.500000
# 75%       3.750000
# max       5.000000

# %%
df
# Out:
#    Region Code    Region Name
# 0            0         Canada
# 1            1        Western
# 2            2       Southern
# 3            3      Northeast
# 4            4        Central
# 5            5  International

# %%
df1 = pd.read_excel("DATA/DIVISION.xls")

# %%
df1.head()
# Out:
#    Division  Division Name
# 0         1  International
# 1         2       Domestic

# %%
df1.describe()
# Out:
#        Division
# count  2.000000
# mean   1.500000
# std    0.707107
# min    1.000000
# 25%    1.250000
# 50%    1.500000
# 75%    1.750000
# max    2.000000

# %%
df1
# Out:
#    Division  Division Name
# 0         1  International
# 1         2       Domestic

# %%
df2 = pd.read_csv("DATA/forecasted_Sales.csv")

# %%
df2.head()
# Out:
#    Month  Forecast  Actual
# 0  March      2145  2247.0
# 1  April      2458     NaN
# 2    May      1245     NaN
# 3   June      5124  3652.0
# 4   July      7421  7514.0

# %%
df2.describe()
# Out:
#           Forecast       Actual
# count    12.000000     8.000000
# mean   4758.833333  5093.125000
# std    2449.600072  2534.626737
# min    1245.000000  1424.000000
# 25%    2552.500000  3300.750000
# 50%    4874.500000  5302.500000
# 75%    6754.250000  7466.750000
# max    8547.000000  7852.000000

# %%
df3 = pd.read_csv("DATA/Products.csv")

# %%
df3.head()
# Out:
#             Product_Line        Product_category  Value
# 0         Sporting Goods      Outdoor Recreation   5642
# 1                   Food     Beverages & Tobacco   2514
# 2  Apparel & Accessories                Clothing   2365
# 3  Apparel & Accessories  Costumes & Accessories   4487
# 4         Sporting Goods               Athletics    812

# %%
df4 = pd.read_csv("DATA/Quaterly_Sales.csv")

# %%
df4.head()
# Out:
#                 Month  SalesVolume
# 0               March       2145.0
# 1               April       2458.0
# 2                 May       1245.0
# 3  Sales Values in Q2          NaN
# 4                June       5124.0

# %%
df4.tail()
# Out:
#        Month  SalesVolume
# 9    October       7846.0
# 10  November       6532.0
# 11  December       4625.0
# 12   January       8547.0
# 13  February       3265.0

# %%
df4.count()
# Out:
# Month          14
# SalesVolume    12
# dtype: int64

# %%
df4.describe()
# Out:
#        SalesVolume
# count    12.000000
# mean   4758.833333
# std    2449.600072
# min    1245.000000
# 25%    2552.500000
# 50%    4874.500000
# 75%    6754.250000
# max    8547.000000

# %%
df5 = pd.read_csv("DATA/Swiggy Bangalore Outlet Details.csv")

# %%
df5.head()
# Out:
#            Shop_Name                                            Cuisine  \
# 0       Kanti Sweets                                             Sweets
# 1      Mumbai Tiffin             North Indian, Home Food, Thalis, Combo
# 2  Sri Krishna sagar  South Indian, North Indian, Fast Food, Beverag...
# 3            Al Daaz  American, Arabian, Chinese, Desserts, Fast Foo...
# 4      Beijing Bites                                      Chinese, Thai
#
#                    Location Rating Cost_for_Two
# 0  Koramangala, Koramangala    4.3        ₹ 150
# 1             Sector 5, HSR    4.4        ₹ 400
# 2    6th Block, Koramangala    4.1        ₹ 126
# 3                  HSR, HSR    4.4        ₹ 400
# 4    5th Block, Koramangala    4.1        ₹ 450

# %%
df5.tail()
# Out:
#               Shop_Name                                            Cuisine  \
# 113  Wok Paper Scissors                          Pan-Asian, Chinese, Asian
# 114  Savoury Restaurant  Arabian, Middle Eastern, North Indian, Grill, ...
# 115         Royal Treat            North Indian, Chinese, Seafood, Biryani
# 116            Thali 99                                       North Indian
# 117  Mani's Dum Biryani                                    Andhra, Biryani
#
#                                Location Rating Cost_for_Two
# 113               JNC Road, Koramangala    3.9        ₹ 219
# 114                       Madiwala, BTM    4.1        ₹ 600
# 115  5th block Koramangala, Koramangala    4.2        ₹ 193
# 116            Koramangala, Koramangala    4.3        ₹ 200
# 117              1st Block, Koramangala    4.2        ₹ 400

# %%
df6 = pd.read_csv("DATA/travel insurance.csv")

# %%
df6.head()
# Out:
#   Agency    Agency Type Distribution Channel                     Product Name  \
# 0    CBH  Travel Agency              Offline               Comprehensive Plan
# 1    CBH  Travel Agency              Offline               Comprehensive Plan
# 2    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 3    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
# 4    CWT  Travel Agency               Online  Rental Vehicle Excess Insurance
#
#   Claim  Duration Destination  Net Sales  Commision (in value) Gender  Age
# 0    No       186    MALAYSIA      -29.0                  9.57      F   81
# 1    No       186    MALAYSIA      -29.0                  9.57      F   71
# 2    No        65   AUSTRALIA      -49.5                 29.70    NaN   32
# 3    No        60   AUSTRALIA      -39.6                 23.76    NaN   32
# 4    No        79       ITALY      -19.8                 11.88    NaN   41

# %%
df6.tail()
# Out:
#       Agency Agency Type Distribution Channel Product Name Claim  Duration  \
# 63321    JZI    Airlines               Online   Basic Plan    No       111
# 63322    JZI    Airlines               Online   Basic Plan    No        58
# 63323    JZI    Airlines               Online   Basic Plan    No         2
# 63324    JZI    Airlines               Online   Basic Plan    No         3
# 63325    JZI    Airlines               Online   Basic Plan    No        22
#
#       Destination  Net Sales  Commision (in value) Gender  Age
# 63321       JAPAN       35.0                 12.25      M   31
# 63322       CHINA       40.0                 14.00      F   40
# 63323    MALAYSIA       18.0                  6.30      M   57
# 63324    VIET NAM       18.0                  6.30      M   63
# 63325   HONG KONG       26.0                  9.10      F   35

# %%
df6.describe()
# Out:
#            Duration     Net Sales  Commision (in value)           Age
# count  63326.000000  63326.000000          63326.000000  63326.000000
# mean      49.317074     40.702018              9.809992     39.969981
# std      101.791566     48.845637             19.804388     14.017010
# min       -2.000000   -389.000000              0.000000      0.000000
# 25%        9.000000     18.000000              0.000000     35.000000
# 50%       22.000000     26.530000              0.000000     36.000000
# 75%       53.000000     48.000000             11.550000     43.000000
# max     4881.000000    810.000000            283.500000    118.000000

# %%
df7 = pd.read_csv("DATA/wine reviews_small.csv")

# %%
df7.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df7.tail()
# Out:
#        Unnamed: 0  country                                        description  \
# 29660       29996       US  A waxy vein of petroleum cuts enticingly throu...
# 29661       29997       US  Loads of purple fruit and baked goods show on ...
# 29662       29998       US  Drenched with dark and rich fruit flavors as w...
# 29663       29999       US  This is an inaugural release of this variety f...
# 29664       30000  Austria  A faint but enticing notion of pink grapefruit...
#
#                            designation  points  price    province  \
# 29660  No. 198 Single Vineyard Reserve      91   19.0    New York
# 29661                          Azimuth      91   54.0  California
# 29662        High Elevation Collection      91   23.0  California
# 29663                              GEO      91   75.0  California
# 29664         Ried Grillenparz Reserve      91   40.0    Kremstal
#
#            region_1       region_2         taster_name taster_twitter_handle  \
# ...

# %%
df7.describe()
# Out:
#          Unnamed: 0        points         price
# count  29665.000000  29665.000000  27540.000000
# mean   15035.887949     88.385539     34.990123
# std     8702.987437      3.010396     40.472213
# min        0.000000     80.000000      4.000000
# 25%     7416.000000     86.000000     17.000000
# 50%    15168.000000     88.000000     25.000000
# 75%    22584.000000     91.000000     42.000000
# max    30000.000000    100.000000   2500.000000

# %%
df8 = pd.read_csv("DATA/100 Sales Records.csv")

# %%
df8.head()
# Out:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority  Order Date   Order ID   Ship Date  Units Sold  \
# 0       Offline              H   5/28/2010  669165933   6/27/2010        9925
# 1        Online              C   8/22/2012  963881480   9/15/2012        2804
# 2       Offline              L  05-02-2014  341417157  05-08-2014        1779
# 3        Online              C   6/20/2014  514321792  07-05-2014        8102
# 4       Offline              L  02-01-2013  115456712  02-06-2013        5062
#
# ...

# %%
df8.tail()
# Out:
#                 Region       Country      Item Type Sales Channel  \
# 95  Sub-Saharan Africa          Mali        Clothes        Online
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub-Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub-Saharan Africa    Mozambique      Household       Offline
#
#    Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 95              M   7/26/2011  512878119  09-03-2011         888      109.28
# 96              L  11-11-2011  810711038  12/28/2011        6267        9.33
# 97              C  06-01-2016  728815257   6/29/2016        1485      154.06
# 98              M   7/30/2015  559427106  08-08-2015        5767       81.73
# 99              L  02-10-2012  665095412   2/15/2012        5367      668.27
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
df8.describe()
# Out:
#            Order ID   Units Sold  Unit Price   Unit Cost  Total Revenue  \
# count  1.000000e+02   100.000000  100.000000  100.000000   1.000000e+02
# mean   5.550204e+08  5128.710000  276.761300  191.048000   1.373488e+06
# std    2.606153e+08  2794.484562  235.592241  188.208181   1.460029e+06
# min    1.146066e+08   124.000000    9.330000    6.920000   4.870260e+03
# 25%    3.389225e+08  2836.250000   81.730000   35.840000   2.687212e+05
# 50%    5.577086e+08  5382.500000  179.880000  107.275000   7.523144e+05
# 75%    7.907551e+08  7369.000000  437.200000  263.330000   2.212045e+06
# max    9.940222e+08  9925.000000  668.270000  524.960000   5.997055e+06
#
#          Total Cost  Total Profit
# count  1.000000e+02  1.000000e+02
# mean   9.318057e+05  4.416820e+05
# std    1.083938e+06  4.385379e+05
# min    3.612240e+03  1.258020e+03
# 25%    1.688680e+05  1.214436e+05
# 50%    3.635664e+05  2.907680e+05
# 75%    1.613870e+06  6.358288e+05
# max    4.509794e+06  1.719922e+06

# %%
df9 = pd.read_excel("DATA/Airline Passengers data.xlsx")

# %%
df9.head()
# Out:
#    Year  Jan  Feb  March  April  May  June  July  Aug  Sept  Oct  Nov  Dec
# 0  2015  200  180    150    280  450   300   280  200   250  350  300  400
# 1  2016  220  199    157    279  484   365   363  346   298  292  311  476
# 2  2017  240  218    164    278  518   338   380  396   399  331  310  445
# 3  2018  260  237    171    277  552   317   399  345   316  316  351  409
# 4  2019  280  256    178    276  586   341   321  352   303  397  370  491

# %%
df9.tail()
# Out:
#    Year  Jan  Feb  March  April  May  June  July  Aug  Sept  Oct  Nov  Dec
# 0  2015  200  180    150    280  450   300   280  200   250  350  300  400
# 1  2016  220  199    157    279  484   365   363  346   298  292  311  476
# 2  2017  240  218    164    278  518   338   380  396   399  331  310  445
# 3  2018  260  237    171    277  552   317   399  345   316  316  351  409
# 4  2019  280  256    178    276  586   341   321  352   303  397  370  491

# %%
df9.describe()
# Out:
#               Year         Jan         Feb       March       April        May  \
# count     5.000000    5.000000    5.000000    5.000000    5.000000    5.00000
# mean   2017.000000  240.000000  218.000000  164.000000  278.000000  518.00000
# std       1.581139   31.622777   30.041638   11.067972    1.581139   53.75872
# min    2015.000000  200.000000  180.000000  150.000000  276.000000  450.00000
# 25%    2016.000000  220.000000  199.000000  157.000000  277.000000  484.00000
# 50%    2017.000000  240.000000  218.000000  164.000000  278.000000  518.00000
# 75%    2018.000000  260.000000  237.000000  171.000000  279.000000  552.00000
# max    2019.000000  280.000000  256.000000  178.000000  280.000000  586.00000
#
#              June        July         Aug        Sept         Oct         Nov  \
# count    5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
# mean   332.200000  348.600000  327.800000  313.200000  337.200000  328.400000
# ...

# %%
Df = pd.read_csv("DATA/crossOverTable.csv")

# %%
Df.head()
# Out:
#   Quarter  Region  Region2  Region3
# 0      Q1     124      421      471
# 1      Q2     415      214      584
# 2      Q3     417      321      582
# 3      Q4     751      256       95

# %%
Df.tail()
# Out:
#   Quarter  Region  Region2  Region3
# 0      Q1     124      421      471
# 1      Q2     415      214      584
# 2      Q3     417      321      582
# 3      Q4     751      256       95

# %%
Df1 = pd.read_excel("DATA/CUSTOMERADDRESS.xls")

# %%
Df1.head()
# Out:
#    Address Number                       City Country  \
# 0        10000000                      Akron      US
# 1        10000453                                 UK
# 2        10000455           Huntington Beach      US
# 3        10000456                   Edmonton      CA
# 4        10000458                    Saginaw      US
#
#                          Customer Address 1  \
# 0                               PO Box 6258
# 1
# 2                         7392 Count Circle
# 3                          8151 Wagner Road
# 4                                PO Box 840
#
#                          Customer Address 2  \
# 0
# 1
# 2
# 3
# 4
#
#                          Customer Address 3  \
# 0
# 1
# 2
# 3
# 4
#
#                          Customer Address 4 State      Zip Code
# 0                                              OH         44312
# 1                                             NaN
# 2                                              CA         92647
# ...

# %%
Df1.tail()
# Out:
#      Address Number      City Country          Customer Address 1  \
# 450        10027560    Odessa      US         3356 Kermit Highway
# 451        10027572      Elma      US             2210 Bowen Road
# 452        10027575    Dallas      US            10400 Plano Road
# 453        10027583    Morton      US   Attention: Charlene Hoyer
# 454        10027629  Dearborn      US  Central Accounting Service
#
#                            Customer Address 2  \
# 450
# 451
# 452
# 453                   500 North Morton Avenue
# 454                               PO Box 6005
#
#                            Customer Address 3  \
# 450
# 451
# 452
# 453                                PO Box 474
# 454
#
#                            Customer Address 4 State    Zip Code
# 450                                              TX       79764
# 451                                              NY       14059
# 452                                              TX       75238
# ...

# %%
Df2 = pd.read_excel("DATA/CUSTOMERS.xls")

# %%
Df2.head()
# Out:
#    Address Number Business Family  Business Unit              Customer  \
# 0        10000000              R3              1      City Supermarket
# 1        10000453              R3              1         A Supermarket
# 2        10000455              R3              1  Caribian Supermarket
# 3        10000456              R1              1              A&B Shop
# 4        10000457              O2              1              A&G Shop
#
#    Customer Number Customer Type  Division Line of Business         Phone  \
# 0         10000000            G2         2                   816-455-8733
# 1         10000453            G1         1                   816-455-8733
# 2         10000455            G2         2                   816-455-8733
# 3         10000456            G3         1                   816-455-8733
# 4         10000457            G1         1                   816-455-8733
#
#    Region Code Regional Sales Mgr Search Type
# 0            4                S16           C
# ...

# %%
Df2.tail()
# Out:
#      Address Number Business Family  Business Unit         Customer  \
# 679        10027560              R2              1       Zilog Shop
# 680        10027572              R3              1  ZipLip.Com Shop
# 681        10027575              R3              1       Zitel Shop
# 682        10027583              R2              1        zNET Shop
# 683        10027629              O2              1      Zocalo Shop
#
#      Customer Number Customer Type  Division Line of Business         Phone  \
# 679         10027560            G2         2                   816-455-8733
# 680         10027572            G2         2                   816-455-8733
# 681         10027575            G2         2                   816-455-8733
# 682         10027583            G2         2                   816-455-8733
# 683         10027629            G2         2                   816-455-8733
#
#      Region Code Regional Sales Mgr Search Type
# 679            2                 S1           C
# ...

# %%
df2.describe()
# Out:
#           Forecast       Actual
# count    12.000000     8.000000
# mean   4758.833333  5093.125000
# std    2449.600072  2534.626737
# min    1245.000000  1424.000000
# 25%    2552.500000  3300.750000
# 50%    4874.500000  5302.500000
# 75%    6754.250000  7466.750000
# max    8547.000000  7852.000000

# %%
Google_play1 = pd.read_csv("DATA/Google Play Store Apps Dataset/googleplaystore.csv")

# %%
Google_play1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
Google_play2 = pd.read_csv("DATA/Google Play Store Apps Dataset/googleplaystore_user_reviews.csv")

# %%
Google_play2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
Google_play2.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
Google_play2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
Exp_data = pd.read_csv("DATA/Expenditure_Data_India_1980_81 to 2015_16_NITI_Aayog/Aggregate_Expenditure.csv",engine="python")

# %%
Exp_data.head()
# Out:
#                State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh     1610    1831    1933    2588    3119    3413    4068
# 1  Arunachal Pradesh       –       –       –       –       –       –     251
# 2              Assam     758     618     691     942    1165    1207    1586
# 3              Bihar    1791    1871    1940    2144    2408    2966    3360
# 4       Chhattisgarh       –       –       –       –       –       –       –
#
#   1987-88 1988-89  ... 2006-07 2007-08   2008-09   2009-10    2010-11  \
# 0    4294    5223  ...   56648   74875  80803.89  85074.79  100635.64
# 1     348     326  ...    2786    3068   4272.59   5236.62    5579.12
# 2    1794    1855  ...   13485   15150  17485.86   24968.3   25946.97
# 3    3914    4324  ...   27136   31573  37181.25  42796.03   50704.52
# 4       –       –  ...   11991   15029  17713.97  21558.72   23564.68
#
#      2011-12    2012-13    2013-14 2014-15 (RE) 2015-16 (BE)
# ...

# %%
Exp_data.tail()
# Out:
#             State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 26  Uttar Pradesh    2668    2942    3490    4116    5186    5331    6225
# 27    Uttarakhand       –       –       –       –       –       –       –
# 28    West Bengal    1552    1838    2072    2181    2738    2974    3508
# 29          Delhi       –       –       –       –       –       –       –
# 30     Puducherry       –       –       –       –       –       –       –
#
#    1987-88 1988-89  ... 2006-07 2007-08    2008-09   2009-10    2010-11  \
# 26    6901    8079  ...   74983   87304  104398.11  121115.3  134585.83
# 27       –       –  ...    8516    9975   10888.79  13297.14   14009.97
# 28    3941    4279  ...   41203   46644   60933.12  68134.03   72962.17
# 29       –       –  ...   12966   18160    20361.3  24925.92   25524.32
# 30       –       –  ...    2387    2588     2956.6   3585.83    4060.98
#
#       2011-12    2012-13    2013-14 2014-15 (RE) 2015-16 (BE)
# ...

# %%
Exp_data.describe()
# Out:
#         2014-15 (RE)   2015-16 (BE)
# count      31.000000      31.000000
# mean    74297.353226   80403.696774
# std     66361.309812   72053.393072
# min      5917.990000    5525.730000
# 25%     12146.310000   14025.845000
# 50%     56430.950000   63602.170000
# 75%    124439.910000  128328.695000
# max    262302.820000  292687.320000

# %%
Exp_data1 = pd.read_csv("DATA/Expenditure_Data_India_1980_81 to 2015_16_NITI_Aayog/Capital_Expenditure.csv",engine="python")

# %%
Exp_data1.head()
# Out:
#                State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh      449     445     427     546     656     633     824
# 1  Arunachal Pradesh       –       –       –       –       –       –      78
# 2              Assam     401     215     208     254     330     264     437
# 3              Bihar     862     704     583     711     721     868    1083
# 4       Chhattisgarh       –       –       –       –       –       –       –
#
#   1987-88 1988-89  ...  2006-07  2007-08   2008-09   2009-10   2010-11  \
# 0     853     977  ...  15210.0  20892.0  18949.67  21626.86  22101.38
# 1     102     111  ...    889.0    809.0   1400.91   1537.88   1834.88
# 2     469     420  ...   2028.0   2406.0   3242.55   3736.12   2995.15
# 3    1295    1113  ...   6551.0   8008.0   8669.68  10211.86  12488.60
# 4       –       –  ...   3188.0   4189.0   3920.27   4293.28   4208.93
#
#     2011-12   2012-13   2013-14 2014-15 (RE) 2015-16 (BE)
# ...

# %%
Exp_data1.tail()
# Out:
#             State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 26  Uttar Pradesh     952    1036    1127    1355    1894    1629    1876
# 27    Uttarakhand       –       –       –       –       –       –       –
# 28    West Bengal     437     527     451     441     588     714     810
# 29          Delhi       –       –       –       –       –       –       –
# 30     Puducherry       –       –       –       –       –       –       –
#
#    1987-88 1988-89  ...  2006-07  2007-08   2008-09   2009-10   2010-11  \
# 26    1821    1822  ...  19284.0  22081.0  28429.22  31741.70  26910.22
# 27       –       –  ...   2039.0   2720.0   2493.43   2639.66   2388.89
# 28     913     804  ...   7042.0   8330.0   9319.79   9634.16   8423.98
# 29       –       –  ...   5211.0   8389.0   8598.75  11025.04  11142.59
# 30       –       –  ...    460.0    387.0    386.13    502.35    520.81
#
#      2011-12   2012-13   2013-14 2014-15 (RE) 2015-16 (BE)
# ...

# %%
Exp_data1.describe()
# Out:
#             2005-06      2006-07       2007-08       2008-09       2009-10  \
# count     30.000000     30.00000     30.000000     31.000000     31.000000
# mean    4288.333333   5241.80000   6009.833333   6752.657097   7345.272258
# std     4348.635262   5081.28927   5824.794625   6993.437091   7570.657703
# min      333.000000    366.00000    387.000000      0.000000      0.000000
# 25%      804.250000    969.50000   1137.500000   1391.250000   1540.800000
# 50%     2256.000000   3425.00000   4371.000000   4329.620000   4701.120000
# 75%     6482.250000   7575.25000   8569.750000   8996.215000  10618.450000
# max    16397.000000  19284.00000  22081.000000  28429.220000  31741.700000
#
#             2010-11       2011-12       2012-13       2013-14  2014-15 (RE)  \
# count     31.000000     31.000000     31.000000     31.000000     31.000000
# mean    7680.535161   9226.217419  10072.813548  10889.440000  14450.423871
# ...

# %%
Exp_data2 = pd.read_csv("DATA/Expenditure_Data_India_1980_81 to 2015_16_NITI_Aayog/Gross_Fiscal_Deficits.csv",engine="python")

# %%
Exp_data2.head()
# Out:
#                 Year 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh    222.1   243.7   172.4     493   591.4     435     804
# 1  Arunachal Pradesh       –       –       –       –       –       –      23
# 2              Assam   -27.4   171.7   200.1   327.2   366.6     154     243
# 3              Bihar   335.8   409.1   434.7     328   395.9     326     461
# 4       Chhattisgarh       –       –       –       –       –       –       –
#
#   1987-88 1988-89  ... 2006-07 2007-08  2008-09  2009-10  2010-11  2011-12  \
# 0     568     673  ...  5640.0  8790.0  12410.0  14010.0  11800.0  15400.0
# 1      38       1  ...  -110.0   -20.0    330.0    500.0    -10.0    990.0
# 2     421     303  ...  -710.0  -790.0  -1410.0   4040.0   1990.0   1650.0
# 3     825     535  ...  3020.0  1710.0   2510.0   5270.0   3970.0   5910.0
# 4       –       –  ...   -30.0   130.0   1030.0   1760.0   -410.0    800.0
#
#    2012-13 2013-14 2014-15 (RE) 2015-16 (BE)
# ...

# %%
Exp_data2.tail()
# Out:
#              Year 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 26  Uttar Pradesh   551.4     452   581.7  1082.3  1493.6    1058    1410
# 27    Uttarakhand       –       –       –       –       –       –       –
# 28    West Bengal   289.2   380.1   497.8   413.9   339.7     259     587
# 29          Delhi       –       –       –       –       –       –       –
# 30     Puducherry     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#    1987-88 1988-89  ...  2006-07  2007-08  2008-09  2009-10  2010-11  2011-12  \
# 26    1014    1802  ...   9620.0  13790.0  20510.0  18690.0  17250.0  15430.0
# 27       –       –  ...    890.0   1740.0   1840.0   2780.0   1840.0   1760.0
# 28     551     579  ...  11430.0  11400.0  13560.0  24950.0  19530.0  17700.0
# 29       –       –  ...    410.0   2040.0   2820.0   3550.0   -730.0   2550.0
# 30     NaN     NaN  ...    400.0    330.0    370.0    580.0    710.0    820.0
#
#     2012-13 2013-14 2014-15 (RE) 2015-16 (BE)
# ...

# %%
Exp_data2.describe()
# Out:
#             2001-02       2002-03       2003-04       2004-05       2005-06  \
# count     29.000000     29.000000     29.000000     29.000000     30.000000
# mean    3310.093103   3521.724138   4243.448276   3767.931034   3004.666667
# std     3363.314340   3627.022656   4845.624150   4457.433902   4062.012185
# min       66.800000     10.000000   -160.000000    190.000000   -360.000000
# 25%      424.200000    540.000000    340.000000    550.000000    280.000000
# 50%     1733.000000   2340.000000   2440.000000   1810.000000   1155.000000
# 75%     4958.000000   5280.000000   5590.000000   5570.000000   4472.500000
# max    11804.100000  14290.000000  17930.000000  18620.000000  17630.000000
#
#             2006-07      2007-08       2008-09       2009-10       2010-11  \
# count     30.000000     30.00000     30.000000     30.000000     30.000000
# mean    2611.333333   2594.00000   4592.666667   6431.333333   5381.666667
# ...

# %%
Exp_data3 = pd.read_csv("DATA/Expenditure_Data_India_1980_81 to 2015_16_NITI_Aayog/Nominal_GSDP_Series.csv",engine="python")

# %%
Exp_data3.head()
# Out:
#                State  1980-81  1981-82  1982-83  1983-84  1984-85  1985-86  \
# 0    Andhra Pradesh    8191.0  10041.0  10844.0  12564.0  13576.0  15266.0
# 1  Arunachal Pradesh    107.0    142.0    166.0    189.0    221.0    269.0
# 2              Assam   2516.0   3228.0   3657.0   4347.0   5113.0   5673.0
# 3              Bihar   7353.0   8562.0   9635.0  10945.0  13004.0  14295.0
# 4       Chhattisgarh      NaN      NaN      NaN      NaN      NaN      NaN
#
#    1986-87  1987-88  1988-89  ...  2007-08  2008-09  2009-10  2010-11  \
# 0  16404.0  19608.0  24732.0  ...   212361   237383   273327   319864
# 1    305.0    330.0    387.0  ...     4810     5687     7474     9021
# 2   6176.0   7001.0   7600.0  ...    71076    81074    95975   112688
# 3  16261.0  17638.0  21181.0  ...   113680   142279   162923   203555
# 4      NaN      NaN      NaN  ...    80255    96972    99364   119420
#
#         2011-12       2012-13       2013-14       2014-15       2015-16  \
# ...

# %%
Exp_data3.describe()
# Out:
#             1980-81       1981-82       1982-83      1983-84       1984-85  \
# count     25.000000     25.000000     25.000000     25.00000     25.000000
# mean    4582.640000   5272.360000   5864.840000   6843.24000   7555.120000
# std     4745.281831   5349.754612   5952.016253   6851.22072   7570.843031
# min       52.000000     59.000000     70.000000     80.00000    102.000000
# 25%      286.000000    339.000000    386.000000    426.00000    474.000000
# 50%     3708.000000   4162.000000   4485.000000   5708.00000   5694.000000
# 75%     7427.000000   8564.000000   9822.000000  11471.00000  13004.000000
# max    16631.000000  18738.000000  20315.000000  23457.00000  25558.000000
#
#             1985-86       1986-87       1987-88       1988-89       1989-90  \
# count     25.000000     25.000000     25.000000     25.000000     25.000000
# mean    8496.320000   9376.200000  10728.600000  12816.200000  14709.200000
# ...

# %%
Exp_data4 = pd.read_csv("DATA/Expenditure_Data_India_1980_81 to 2015_16_NITI_Aayog/Own_Tax_Revenues.csv",engine="python")

# %%
Exp_data4.head()
# Out:
#                State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh      582     703     808     965    1174    1439    1559
# 1  Arunachal Pradesh       –       –       –       –       –       –       2
# 2              Assam      66      90     108     136     189     235     245
# 3              Bihar     277     338     382     442     464     576     659
# 4       Chhattisgarh       –       –       –       –       –       –       –
#
#   1987-88 1988-89  ...  2006-07  2007-08  2008-09  2009-10  2010-11  2011-12  \
# 0    1819    2122  ...  23930.0  28790.0  33360.0  35180.0  45140.0  53280.0
# 1       2       2  ...     80.0    100.0    140.0    170.0    210.0    320.0
# 2     249     279  ...   3480.0   3360.0   4150.0   4990.0   5930.0   7640.0
# 3     761     831  ...   4030.0   5090.0   6170.0   8090.0   9870.0  12610.0
# 4       –       –  ...   5050.0   5620.0   6590.0   7120.0   9010.0  10710.0
#
#    2012-13  2013-14  2014-15  2015-16
# ...

# %%
Exp_data5 = pd.read_csv("DATA/Expenditure_Data_India_1980_81 to 2015_16_NITI_Aayog/Revenue_Deficits.csv",engine="python")

# %%
Exp_data5.head()
# Out:
#                State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh     -104     -80  -132.6    88.6     169     7.3     189
# 1  Arunachal Pradesh       –       –       –       –       –       –     -39
# 2              Assam    -165    36.8    43.9   137.2   135.8     5.6     -61
# 3              Bihar     -59       7    37.7   -72.1  -106.7  -297.7    -346
# 4       Chhattisgarh       –       –       –       –       –       –       –
#
#   1987-88 1988-89  ... 2006-07 2007-08 2008-09 2009-10 2010-11 2011-12  \
# 0     -37     -33  ... -2807.0  -159.0 -1000.0 -1230.0 -2460.0 -3140.0
# 1     -50     -93  ...  -695.0  -743.0  -980.0  -600.0 -1680.0 -1080.0
# 2      84    62.1  ... -2210.0 -2581.0 -3830.0  1350.0   -50.0  -930.0
# 3    -190  -277.5  ... -2498.0 -4645.0 -4470.0 -2940.0 -6320.0 -4820.0
# 4       –       –  ... -2647.0 -3039.0 -1870.0  -890.0 -3360.0 -3240.0
#
#   2012-13 2013-14 2014-15 2015-16 (RE)
# ...

# %%
Exp_data6 = pd.read_csv("DATA/Expenditure_Data_India_1980_81 to 2015_16_NITI_Aayog/Revenue_Expenditure.csv",engine="python")

# %%
Exp_data6.head()
# Out:
#                State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh     1161    1386    1507    2042    2463    2781    3245
# 1  Arunachal Pradesh       –       –       –       –       –       –     173
# 2              Assam     357     402     483     688     835     943    1149
# 3              Bihar     929    1167    1357    1432    1687    2098    2277
# 4       Chhattisgarh       –       –       –       –       –       –       –
#
#   1987-88 1988-89  ...  2006-07  2007-08   2008-09   2009-10   2010-11  \
# 0    3441    4246  ...  41438.0  53984.0  61854.22  63447.93  78534.26
# 1     246     214  ...   1897.0   2260.0   2871.68   3698.74   3744.24
# 2    1326    1435  ...  11457.0  12744.0  14243.31  21232.18  22951.82
# 3    2619    3211  ...  20585.0  23565.0  28511.57  32584.17  38215.92
# 4       –       –  ...   8802.0  10840.0  13793.70  17265.44  19355.75
#
#     2011-12    2012-13    2013-14 2014-15 (RE) 2015-16 (BE)
# ...

# %%
Exp_data7 = pd.read_csv("DATA/Expenditure_Data_India_1980_81 to 2015_16_NITI_Aayog/Social_Sector_Expenditure.csv",engine="python")

# %%
Exp_data7.head()
# Out:
#                State 1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# 0    Andhra Pradesh      532     613     697    1073    1193    1470    1849
# 1  Arunachal Pradesh       –       –       –       –       –       –      78
# 2              Assam     171     176     215     339     382     467     597
# 3              Bihar     452     598     673     677     758    1231    1353
# 4       Chhattisgarh       –       –       –       –       –       –       –
#
#   1987-88 1988-89  ...  2006-07  2007-08  2008-09  2009-10  2010-11  2011-12  \
# 0    1884    2103  ...  18654.0  24471.0  31440.0  30280.0  39130.0  45400.0
# 1     102     113  ...    843.0    953.0   1280.0   1770.0   1570.0   2160.0
# 2     681     727  ...   5220.0   6056.0   6760.0   9160.0  10240.0  11190.0
# 3    1431    1849  ...  11127.0  13815.0  16340.0  17870.0  19370.0  24050.0
# 4       –       –  ...   5707.0   6947.0   8870.0  11680.0  11820.0  14810.0
#
#    2012-13 2013-14 2014-15 2015-16 (RE)
# ...
